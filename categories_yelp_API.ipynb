# %%
import requests
import matplotlib.pyplot as plt 
import pandas as pd
import json 
import csv 
#from IPython.display import Image
# %matplotlib inline

# %%
api_keys = pd.read_csv('api_keys.csv')
#.ipynb_checkpoints

# %%
api_key = api_keys.loc[api_keys['endpoint'] == 'yelp', 'key'].values[0]

# %%
end_point_category = 'https://api.yelp.com/v3/businesses/search'

# %%
header_category_nash = {'Authorization': 'bearer %s' % api_key}

# %% [markdown]
# # top bars

# %%
params_offset = 50

# %%
def extract_bars_info(bars):
    review_count = bars['review_count']
    categories =  [a['title'] for a in bars['categories']]
    ratings = bars['rating']
    name = bars['name']
    latitude = bars['coordinates']['latitude']
    longitude = bars['coordinates']['longitude']
    try:
        price = bars['price']
    except:
        price = 'no price'
    zip_code = bars['location']['zip_code']
    output_dict_bars = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_bars

# %%
bar_list = []
for increment in range(0, 500, 50) : 
    print(increment)
    params_category_bar = {'location': 'Nashville', 'limit': 50, 'categories': 'bars', 'offset': increment}

    response_business_bar = requests.get(url = end_point_category, params = params_category_bar, headers = header_category_nash)
    print(response_business_bar)
    for bar in response_business_bar.json()['businesses']:
        bar_dict = extract_bars_info(bar)
        bar_list.append(bar_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>

# %%
bars_nash = pd.DataFrame(bar_list)

# %%
bars_nash
# Out:
#      review_count                             categories  ratings  \
# 0            2286                 [American (New), Bars]      4.5
# 1            1209                 [Italian, Pizza, Bars]      4.5
# 2            2889         [Bars, American (Traditional)]      4.0
# 3            1301                        [Mexican, Bars]      4.5
# 4            1114                          [Tacos, Bars]      4.5
# ..            ...                                    ...      ...
# 439             2                 [Hookah Bars, Lounges]      1.0
# 440             2                    [Bars, Dance Clubs]      3.0
# 441             1                          [Sports Bars]      1.0
# 442             1  [Hookah Bars, American (Traditional)]      1.0
# 443             1                                 [Bars]      2.0
#
#                             name   latitude  longitude     price zip_code
# 0                   The Stillery  36.162250 -86.775700        $$    37201
# ...

# %%
bars_nash.shape
# Out:
# (444, 8)

# %%
bars_nash.to_csv('bars_nash.csv')

# %% [markdown]
# # top  restaurants

# %%
def extract_restaurants_info(restaurants):
    review_count = restaurants['review_count']
    categories =  [a['title'] for a in restaurants['categories']]
    ratings = restaurants['rating']
    name = restaurants['name']
    latitude = restaurants['coordinates']['latitude']
    longitude = restaurants['coordinates']['longitude']
    try:
        price = restaurants['price']
    except:
        price = 'no price'
    zip_code = restaurants['location']['zip_code']
    output_dict_restaurants = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_restaurants

# %%
restaurants_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_restaurants = {'location': 'Nashville', 'limit': 50, 'categories': 'restaurants', 'offset': increment}

    response_business_restaurants_list_nash = requests.get(url = end_point_category, params = params_category_restaurants, headers = header_category_nash)
    print(response_business_restaurants_list_nash)
    for restaurants in response_business_restaurants_list_nash.json()['businesses']:
        restaurants_dict = extract_restaurants_info(restaurants)
        restaurants_list.append(restaurants_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
restaurants_list_nash = pd.DataFrame(restaurants_list)

# %%
restaurants_list_nash.shape
# Out:
# (1000, 8)

# %%
restaurants_list_nash.to_csv('restaurants_nash.csv')

# %% [markdown]
# # top 50 activities

# %%
def extract_activities_info(activities):
    review_count = activities['review_count']
    categories =  [a['title'] for a in activities['categories']]
    ratings = activities['rating']
    name = activities['name']
    latitude = activities['coordinates']['latitude']
    longitude = activities['coordinates']['longitude']
    try:
        price = activities['price']
    except:
        price = 'no price'
    zip_code = activities['location']['zip_code']
    output_dict_activities = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_activities

# %%
activities_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_activities = {'location': 'Nashville', 'limit': 50, 'categories': 'active', 'offset': increment}

    response_business_activities_list_nash = requests.get(url = end_point_category, params = params_category_activities, headers = header_category_nash)
    print(response_business_activities_list_nash)
    for activities in response_business_activities_list_nash.json()['businesses']:
        activities_dict = extract_activities_info(activities)
        activities_list.append(activities_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
activities_list = pd.DataFrame(activities_list)

# %%
activities_list
# Out:
#      review_count                                         categories  ratings  \
# 0             217           [Escape Games, Team Building Activities]      5.0
# 1             187                                            [Parks]      4.5
# 2             111           [Escape Games, Team Building Activities]      5.0
# 3             195                                            [Parks]      4.5
# 4             105                                    [Hiking, Parks]      4.5
# ..            ...                                                ...      ...
# 424             5                    [Campgrounds, Rafting/Kayaking]      5.0
# 425             3                        [Rafting/Kayaking, Fishing]      5.0
# 426             2                        [Arcades, Laser Tag, Pizza]      1.5
# 427             1  [Summer Camps, Community Service/Non-Profit, B...      5.0
# 428             8                        [Rafting/Kayaking, Boating]      4.5
#
# ...

# %%
activities_list.to_csv("activities_nash.csv")

# %% [markdown]
# # Top for pets

# %%
def extract_pets_info(pets):
    review_count = pets['review_count']
    categories =  [a['title'] for a in pets['categories']]
    ratings = pets['rating']
    name = pets['name']
    latitude = pets['coordinates']['latitude']
    longitude = pets['coordinates']['longitude']
    try:
        price = pets['price']
    except:
        price = 'no price'
    zip_code = pets['location']['zip_code']
    output_dict_pets = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_pets

# %%
pets_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_pets = {'location': 'Nashville', 'limit': 50, 'categories': 'pets', 'offset': increment}

    response_business_pets_list_nash = requests.get(url = end_point_category, params = params_category_pets, headers = header_category_nash)
    print(response_business_pets_list_nash)
    for pets in response_business_pets_list_nash.json()['businesses']:
        pets_dict = extract_pets_info(pets)
        pets_list.append(pets_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
pets_list = pd.DataFrame(pets_list)

# %%
pets_list
# Out:
#      review_count                                         categories  ratings  \
# 0              80                                    [Veterinarians]      5.0
# 1              51                                       [Pet Stores]      5.0
# 2              45                                      [Pet Sitting]      5.0
# 3              41          [Pet Sitting, Pet Training, Pet Groomers]      5.0
# 4              53                                    [Veterinarians]      4.5
# ..            ...                                                ...      ...
# 175             1  [Home & Rental Insurance, Auto Insurance, Pet ...      5.0
# 176             1                                     [Pet Training]      5.0
# 177             1                                     [Pet Training]      5.0
# 178             2                                     [Pet Breeders]      5.0
# 179             1                     [Fences & Gates, Pet Services]      5.0
#
# ...

# %%
pets_list.to_csv("pets_nash.csv")

# %% [markdown]
# # Top shopping

# %%
def extract_shopping_info(shopping):
    review_count = shopping['review_count']
    categories =  [a['title'] for a in shopping['categories']]
    ratings = shopping['rating']
    name = shopping['name']
    latitude = shopping['coordinates']['latitude']
    longitude = shopping['coordinates']['longitude']
    try:
        price = shopping['price']
    except:
        price = 'no price'
    zip_code = shopping['location']['zip_code']
    output_dict_shopping = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_shopping

# %%
shopping_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_shopping = {'location': 'Nashville', 'limit': 50, 'categories': 'shopping', 'offset': increment}

    response_business_shopping_list_nash = requests.get(url = end_point_category, params = params_category_shopping, headers = header_category_nash)
    print(response_business_shopping_list_nash)
    for shopping in response_business_shopping_list_nash.json()['businesses']:
        shopping_dict = extract_shopping_info(shopping)
        shopping_list.append(shopping_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
shopping_list = pd.DataFrame(shopping_list)

# %%
shopping_list
# Out:
#      review_count                                         categories  ratings  \
# 0             379      [Tapas Bars, American (New), Cooking Classes]      4.5
# 1             103                            [Jewelry, Watch Repair]      5.0
# 2             151                      [Vinyl Records, Music & DVDs]      4.5
# 3              79  [Sewing & Alterations, Men's Clothing, Bespoke...      5.0
# 4             150                      [Music & DVDs, Vinyl Records]      4.5
# ..            ...                                                ...      ...
# 995             8  [Mobile Phones, Electronics, Mobile Phone Acce...      1.5
# 996             3                   [Truck Rental, Packing Supplies]      2.5
# 997             2                                 [Furniture Stores]      3.5
# 998             4                                   [Men's Clothing]      2.5
# 999             3                                       [Mattresses]      2.5
#
# ...

# %%
shopping_list.to_csv("shopping_nash.csv")

# %% [markdown]
# # top 50 gyms

# %%
def extract_gyms_info(gyms):
    review_count = gyms['review_count']
    categories =  [a['title'] for a in gyms['categories']]
    ratings = gyms['rating']
    name = gyms['name']
    latitude = gyms['coordinates']['latitude']
    longitude = gyms['coordinates']['longitude']
    try:
        price = gyms['price']
    except:
        price = 'no price'
    zip_code = gyms['location']['zip_code']
    output_dict_gyms = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_gyms

# %%
gyms_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_gyms = {'location': 'Nashville', 'limit': 50, 'categories': 'gyms', 'offset': increment}

    response_business_gyms_list_nash = requests.get(url = end_point_category, params = params_category_gyms, headers = header_category_nash)
    print(response_business_gyms_list_nash)
    for gyms in response_business_gyms_list_nash.json()['businesses']:
        gyms_dict = extract_gyms_info(gyms)
        gyms_list.append(gyms_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
gyms_list = pd.DataFrame(gyms_list)

# %%
gyms_list
# Out:
#     review_count                                         categories  ratings  \
# 0             27                           [Interval Training Gyms]      5.0
# 1             72                      [Gyms, Child Care & Day Care]      4.0
# 2             39                       [Boot Camps, Gyms, Trainers]      4.5
# 3             50                       [Gyms, Trainers, Kickboxing]      4.5
# 4             43  [Trainers, Cycling Classes, Interval Training ...      4.5
# ..           ...                                                ...      ...
# 77             1                                   [Gyms, Trainers]      5.0
# 78             9                    [Gyms, Trainers, Nutritionists]      3.0
# 79             3  [Trainers, Interval Training Gyms, Nutritionists]      3.5
# 80             8                     [Gyms, Trainers, Tanning Beds]      3.5
# 81             1                           [Trainers, Gyms, Boxing]      2.0
#
# ...

# %%
gyms_list.to_csv("gyms_nash.csv")

# %% [markdown]
# # Pull in Denver

# %% [markdown]
# # Denver bars

# %%
def extract_bars_den_info(bars_den):
    review_count = bars_den['review_count']
    categories =  [a['title'] for a in bars_den['categories']]
    ratings = bars_den['rating']
    name = bars_den['name']
    latitude = bars_den['coordinates']['latitude']
    longitude = bars_den['coordinates']['longitude']
    try:
        price = bars_den['price']
    except:
        price = 'no price'
    zip_code = bars_den['location']['zip_code']
    output_dict_bars_den = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_bars_den

# %%
bars_den_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_bars_den = {'location': 'Denver', 'limit': 50, 'categories': 'bars', 'offset': increment}

    response_business_bars_den = requests.get(url = end_point_category, params = params_category_bars_den, headers = header_category_nash)
    print(response_business_bars_den)
    for bars_den in response_business_bars_den.json()['businesses']:
        bars_den_dict = extract_bars_den_info(bars_den)
        bars_den_list.append(bars_den_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
bars_den_list = pd.DataFrame(bars_den_list)

# %%
bars_den_list
# Out:
#      review_count                                        categories  ratings  \
# 0            2230                   [American (New), Spanish, Bars]      4.5
# 1            3382          [Asian Fusion, Breakfast & Brunch, Bars]      4.0
# 2            1457   [American (New), Latin American, Cocktail Bars]      4.5
# 3            1833                      [Japanese, Sushi Bars, Bars]      4.5
# 4            2743       [Diners, Breakfast & Brunch, Cocktail Bars]      4.0
# ..            ...                                               ...      ...
# 784             2                    [Bars, American (Traditional)]      1.0
# 785             1             [Bars, American (Traditional), Delis]      4.0
# 786             2                         [Lounges, Latin American]      1.0
# 787             2  [Sports Bars, Dance Clubs, Beer, Wine & Spirits]      1.5
# 788             1                                            [Bars]      1.0
#
# ...

# %%
bars_den_list.to_csv("bars_den.csv")

# %% [markdown]
# # Denver restaurants

# %%
def extract_restaurants_den_info(restaurants_den):
    review_count = restaurants_den['review_count']
    categories =  [a['title'] for a in restaurants_den['categories']]
    ratings = restaurants_den['rating']
    name = restaurants_den['name']
    latitude = restaurants_den['coordinates']['latitude']
    longitude = restaurants_den['coordinates']['longitude']
    try:
        price = restaurants_den['price']
    except:
        price = 'no price'
    zip_code = restaurants_den['location']['zip_code']
    output_dict_restaurants_den = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_restaurants_den

# %%
restaurants_den_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_restaurants_den = {'location': 'Denver', 'limit': 50, 'categories': 'restaurants', 'offset': increment}

    response_business_restaurants_den = requests.get(url = end_point_category, params = params_category_restaurants_den, headers = header_category_nash)
    print(response_business_restaurants_den)
    for restaurants_den in response_business_restaurants_den.json()['businesses']:
        restaurants_den_dict = extract_gyms_info(restaurants_den)
        restaurants_den_list.append(restaurants_den_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
restaurants_den_list = pd.DataFrame(restaurants_den_list)

# %%
restaurants_den_list
# Out:
#      review_count                                         categories  ratings  \
# 0            3716                   [Sandwiches, Breakfast & Brunch]      4.5
# 1            4192  [Breakfast & Brunch, Sandwiches, American (Tra...      4.5
# 2            3377                [American (New), Vegan, Vegetarian]      4.5
# 3            2230                    [American (New), Spanish, Bars]      4.5
# 4            3382           [Asian Fusion, Breakfast & Brunch, Bars]      4.0
# ..            ...                                                ...      ...
# 995           203              [American (Traditional), Sports Bars]      3.0
# 996            77                       [Italian, Pizza, Sandwiches]      4.0
# 997           150                                          [Italian]      3.5
# 998           159                    [Italian, American (New), Bars]      4.0
# 999           118                    [Pizza, American (Traditional)]      3.5
#
# ...

# %%
restaurants_den_list.to_csv("restaurants_den.csv")

# %% [markdown]
# # denver activities

# %%
def extract_activities_den_info(activities_den):
    review_count = activities_den['review_count']
    categories =  [a['title'] for a in activities_den['categories']]
    ratings = activities_den['rating']
    name = activities_den['name']
    latitude = activities_den['coordinates']['latitude']
    longitude = activities_den['coordinates']['longitude']
    try:
        price = activities_den['price']
    except:
        price = 'no price'
    zip_code = activities_den['location']['zip_code']
    output_dict_activities_den = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_activities_den

# %%
activities_den_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_activities_den = {'location': 'Denver', 'limit': 50, 'categories': 'active', 'offset': increment}

    response_business_activities_den = requests.get(url = end_point_category, params = params_category_activities_den, headers = header_category_nash)
    print(response_business_activities_den)
    for activities_den in response_business_activities_den.json()['businesses']:
        activities_den_dict = extract_activities_den_info(activities_den)
        activities_den_list.append(activities_den_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
activities_den_list = pd.DataFrame(activities_den_list)

# %%
activities_den_list
# Out:
#      review_count                                categories  ratings  \
# 0             673      [Stadiums & Arenas, Baseball Fields]      4.0
# 1             181                         [Scooter Rentals]      5.0
# 2             644                                    [Zoos]      4.0
# 3             288  [Escape Games, Team Building Activities]      4.5
# 4             104                            [Escape Games]      5.0
# ..            ...                                       ...      ...
# 995             1                                 [Pilates]      5.0
# 996             4                                    [Yoga]      3.5
# 997             1      [Sports Clubs, Amateur Sports Teams]      5.0
# 998             2                            [Summer Camps]      3.0
# 999             1                                   [Parks]      2.0
#
#                                                   name   latitude   longitude  \
# ...

# %%
activities_den_list.to_csv("activities_den.csv")

# %% [markdown]
# # denver pets

# %%
def extract_pets_den_info(pets_den):
    review_count = pets_den['review_count']
    categories =  [a['title'] for a in pets_den['categories']]
    ratings = pets_den['rating']
    name = pets_den['name']
    latitude = pets_den['coordinates']['latitude']
    longitude = pets_den['coordinates']['longitude']
    try:
        price = pets_den['price']
    except:
        price = 'no price'
    zip_code = pets_den['location']['zip_code']
    output_dict_pets_den = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_pets_den

# %%
pets_den_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_pets_den = {'location': 'Denver', 'limit': 50, 'categories': 'pets', 'offset': increment}

    response_business_pets_den = requests.get(url = end_point_category, params = params_category_pets_den, headers = header_category_nash)
    print(response_business_pets_den)
    for pets_den in response_business_pets_den.json()['businesses']:
        pets_den_dict = extract_pets_den_info(pets_den)
        pets_den_list.append(pets_den_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
pets_den_list = pd.DataFrame(pets_den_list)

# %%
pets_den_list
# Out:
#      review_count                                 categories  ratings  \
# 0             222  [Pet Sitting, Pet Groomers, Pet Training]      4.5
# 1             157                              [Pet Sitting]      4.5
# 2             165  [Coffee & Tea, Pet Adoption, Art Classes]      4.5
# 3             132                 [Pet Services, Pet Stores]      4.5
# 4              98               [Pet Training, Pet Boarding]      5.0
# ..            ...                                        ...      ...
# 619             2                 [Dog Walkers, Pet Sitting]      3.0
# 620             1              [Pet Services, Photographers]      5.0
# 621             2                             [Pet Boarding]      5.0
# 622             1    [Auto Detailing, Handyman, Pet Sitting]      1.0
# 623            11               [Pet Sitting, House Sitters]      5.0
#
#                             name   latitude   longitude     price zip_code
# ...

# %%
pets_den_list.to_csv("pets_den.csv")

# %% [markdown]
# # Denver shopping

# %%
def extract_shopping_den_info(shopping_den):
    review_count = shopping_den['review_count']
    categories =  [a['title'] for a in shopping_den['categories']]
    ratings = shopping_den['rating']
    name = shopping_den['name']
    latitude = shopping_den['coordinates']['latitude']
    longitude = shopping_den['coordinates']['longitude']
    try:
        price = shopping_den['price']
    except:
        price = 'no price'
    zip_code = shopping_den['location']['zip_code']
    output_dict_shopping_den = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_shopping_den

# %%
shopping_den_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_shopping_den = {'location': 'Denver', 'limit': 50, 'categories': 'shopping', 'offset': increment}

    response_business_shopping_den = requests.get(url = end_point_category, params = params_category_shopping_den, headers = header_category_nash)
    print(response_business_shopping_den)
    for shopping_den in response_business_shopping_den.json()['businesses']:
        shopping_den_dict = extract_shopping_den_info(shopping_den)
        shopping_den_list.append(shopping_den_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
shopping_den_list = pd.DataFrame(shopping_den_list)

# %%
shopping_den_list
# Out:
#      review_count                                         categories  ratings  \
# 0             504                         [Bookstores, Coffee & Tea]      4.5
# 1             301             [Coffee & Tea, Sandwiches, Gift Shops]      4.5
# 2             257  [Beer, Wine & Spirits, Coffee & Tea, Art Galle...      4.5
# 3             277                                [Piercing, Jewelry]      4.5
# 4             243   [Sewing & Alterations, Women's Clothing, Bridal]      5.0
# ..            ...                                                ...      ...
# 995             5                        [Antiques, Interior Design]      4.5
# 996             4  [Medical Spas, Skin Care, Cosmetics & Beauty S...      5.0
# 997            19                              [Framing, Home Decor]      4.5
# 998             6  [Used, Vintage & Consignment, Vinyl Records, G...      4.5
# 999            17          [Countertop Installation, Kitchen & Bath]      3.0
#
# ...

# %%
shopping_den_list.to_csv("shopping_den.csv")

# %% [markdown]
# # denver gyms

# %%
def extract_gyms_den_info(gyms_den):
    review_count = gyms_den['review_count']
    categories =  [a['title'] for a in gyms_den['categories']]
    ratings = gyms_den['rating']
    name = gyms_den['name']
    latitude = gyms_den['coordinates']['latitude']
    longitude = gyms_den['coordinates']['longitude']
    try:
        price = gyms_den['price']
    except:
        price = 'no price'
    zip_code = gyms_den['location']['zip_code']
    output_dict_gyms_den = {'review_count': review_count, 
                   'categories': categories, 
                   'ratings': ratings,
                   'name': name, 
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code}
    return output_dict_gyms_den

# %%
gyms_den_list = []
for increment in range(0, 1000, 50) : 
    print(increment)
    params_category_gyms_den = {'location': 'Denver', 'limit': 50, 'categories': 'gyms', 'offset': increment}

    response_business_gyms_den = requests.get(url = end_point_category, params = params_category_gyms_den, headers = header_category_nash)
    print(response_business_gyms_den)
    for gyms_den in response_business_gyms_den.json()['businesses']:
        gyms_den_dict = extract_gyms_info(gyms_den)
        gyms_den_list.append(gyms_den_dict)
        params_offset += 50
# Out:
# 0
# <Response [200]>
# 50
# <Response [200]>
# 100
# <Response [200]>
# 150
# <Response [200]>
# 200
# <Response [200]>
# 250
# <Response [200]>
# 300
# <Response [200]>
# 350
# <Response [200]>
# 400
# <Response [200]>
# 450
# <Response [200]>
# 500
# <Response [200]>
# 550
# <Response [200]>
# 600
# <Response [200]>
# 650
# <Response [200]>
# 700
# <Response [200]>
# 750
# <Response [200]>
# 800
# <Response [200]>
# 850
# <Response [200]>
# 900
# <Response [200]>
# 950
# <Response [200]>

# %%
gyms_den_list = pd.DataFrame(gyms_den_list)

# %%
gyms_den_list
# Out:
#      review_count                                categories  ratings  \
# 0             100                          [Trainers, Gyms]      5.0
# 1              54   [Gyms, Cycling Classes, Cardio Classes]      5.0
# 2              60  [Yoga, Interval Training Gyms, Trainers]      5.0
# 3              68            [Gyms, Trainers, Martial Arts]      5.0
# 4              52                          [Gyms, Trainers]      5.0
# ..            ...                                       ...      ...
# 199             1                                    [Gyms]      5.0
# 200             1                     [Dance Studios, Gyms]      5.0
# 201             1                                    [Gyms]      5.0
# 202             1                                    [Gyms]      4.0
# 203             1               [Gyms, Appliances & Repair]      1.0
#
#                               name   latitude   longitude     price zip_code
# ...

# %%
gyms_den_list.to_csv("gyms_den.csv")
